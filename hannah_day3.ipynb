# %%
import numpy as np
from netCDF4 import Dataset
import glob
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

for file in list(glob.glob('*.nc')):
    fh = Dataset(file,'r')
    flag = fh.variables['SOL_AZIM'][:]
    lat = fh.variables['LAT_GIN'][:]
    lon = fh.variables['LON_GIN'][:]
    fh.variables.keys()
    fh.close()
    
#x,y = m(lat,lon)

# %%
import numpy as np
from netCDF4 import Dataset
import glob
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import math
import mplleaflet
# %matplotlib inline

fh = Dataset('core_faam_20160303_v004_r0_b947.nc','r')
lat = fh.variables['LAT_GIN'][:]

lat[lat==0]=-9999
lat[lat==-9999]=['nan']
lon = fh.variables['LON_GIN'][:]
lon[lon==0]=-9999
lon[lon==-9999]=['nan']
#mois = fh.variables['NV_LWC_U'][:]
max_lat = np.nanmax(lat)
min_lat = np.nanmin(lat) 
max_lon = np.nanmax(lon) 
min_lon = np.nanmin(lon)

max_lat = max_lat +0.5
min_lat = min_lat -0.5
max_lon = max_lon +0.5
min_lon = min_lon -0.5

#plt.plot(lon,lat)
#plt.xlabel('Longtitude')
#plt.xlabel('Latitude')
#plt.title('Flight Path: Skegness')
#print(max_lat)
#print(min_lat)
#print(max_lon)
#print(min_lon)

fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
m = Basemap(llcrnrlon=min_lon,llcrnrlat=min_lat,urcrnrlon=max_lon,urcrnrlat=max_lat, resolution='i', projection='merc', lat_0 = 40., lon_0 = -80)
m.drawcoastlines()
m.drawmapboundary(fill_color='aqua') 
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')
parallels = np.arange(0.,81,10.)

x,y = m(lon,lat)
m.plot(x,y,'k',label='Flight Path')

plt.show()
# Out:
# C:\Users\Ben\Anaconda3\lib\site-packages\ipykernel\__main__.py:13: MaskedArrayFutureWarning: setting an item on a masked array which has a shared mask will not copy the mask and also change the original mask array in the future.
# Check the NumPy 1.11 release notes for more information.
# C:\Users\Ben\Anaconda3\lib\site-packages\ipykernel\__main__.py:16: MaskedArrayFutureWarning: setting an item on a masked array which has a shared mask will not copy the mask and also change the original mask array in the future.
# Check the NumPy 1.11 release notes for more information.

# %%
import numpy as np
from netCDF4 import Dataset
import glob
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import math


fh = Dataset('core_faam_20160303_v004_r0_b947.nc','r')
lat = fh.variables['LAT_GIN'][:]

lat[lat==0]=-9999
lat[lat==-9999]=['nan']
lon = fh.variables['LON_GIN'][:]
lon[lon==0]=-9999
lon[lon==-9999]=['nan']
alt = fh.variables['HGT_RADR'][:]
#mois = fh.variables['NV_LWC_U'][:]
max_lat = np.nanmax(lat)
min_lat = np.nanmin(lat) 
max_lon = np.nanmax(lon) 
min_lon = np.nanmin(lon)

max_lat = max_lat +0.5
min_lat = min_lat -0.5
max_lon = max_lon +0.5
min_lon = min_lon -0.5

fig = plt.figure()
# Out:
# /home/hapr/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:13: MaskedArrayFutureWarning: setting an item on a masked array which has a shared mask will not copy the mask and also change the original mask array in the future.
# Check the NumPy 1.11 release notes for more information.
# /home/hapr/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:16: MaskedArrayFutureWarning: setting an item on a masked array which has a shared mask will not copy the mask and also change the original mask array in the future.
# Check the NumPy 1.11 release notes for more information.

# %%
import numpy as np
from netCDF4 import Dataset
import glob
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import math
# %matplotlib inline

fh = Dataset('core_faam_20160303_v004_r0_b947.nc','r')
lat = fh.variables['LAT_GIN'][:]

lat[lat==0]=-9999
lat[lat==-9999]=['nan']
lon = fh.variables['LON_GIN'][:]
lon[lon==0]=-9999
lon[lon==-9999]=['nan']
#mois = fh.variables['NV_LWC_U'][:]
max_lat = np.nanmax(lat)
min_lat = np.nanmin(lat) 
max_lon = np.nanmax(lon) 
min_lon = np.nanmin(lon)

max_lat = max_lat +0.5
min_lat = min_lat -0.5
max_lon = max_lon +0.5
min_lon = min_lon -0.5

#plt.plot(lon,lat)
#plt.xlabel('Longtitude')
#plt.xlabel('Latitude')
#plt.title('Flight Path: Skegness')
#print(max_lat)
#print(min_lat)
#print(max_lon)
#print(min_lon)

fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
m = Basemap(llcrnrlon=min_lon,llcrnrlat=min_lat,urcrnrlon=max_lon,urcrnrlat=max_lat, resolution='i', projection='merc', lat_0 = 40., lon_0 = -80)
m.drawcoastlines()
m.drawmapboundary(fill_color='aqua') 
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')
parallels = np.arange(0.,81,10.)

x,y = m(lon,lat)
m.plot(x,y,'k',label='Flight Path')

plt.show()
# Out:
# /home/hapr/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:13: MaskedArrayFutureWarning: setting an item on a masked array which has a shared mask will not copy the mask and also change the original mask array in the future.
# Check the NumPy 1.11 release notes for more information.
# /home/hapr/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:16: MaskedArrayFutureWarning: setting an item on a masked array which has a shared mask will not copy the mask and also change the original mask array in the future.
# Check the NumPy 1.11 release notes for more information.

# %%
import numpy as np
from netCDF4 import Dataset
import glob
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import math


fh = Dataset('core_faam_20160303_v004_r0_b947.nc','r')
wow=fh.variables['WOW_IND'][:]
lat = fh.variables['LAT_GIN'][:]
time = fh.variables['Time'][:]
PALT_RVS = fh.variables['PALT_RVS'][:]
TAT_DI_R = fh.variables['TAT_DI_R'][:]
len_tat=len(TAT_DI_R)
TempProfile=np.array(TAT_DI_R)

for i in range (0,len(PALT_RVS),1):
    if PALT_RVS[i]<=(PALT_RVS[i+32]-2):
        TempProfile[i]=1
    elif PALT_RVS[i]>=(PALT_RVS[i+32]+2):
        TempProfile[i]=2
    else:
        TempProfile[i]=0 



plt.plot(time,PALT_RVS)
plt.plot(time,TempProfile)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-7cc6a30eacf9> in <module>()
#      12 lat = fh.variables['LAT_GIN'][:]
#      13 time = fh.variables['Time'][:]
# ---> 14 PALT_RVS = fh.variables['PAL_RVS'][:]
#      15 TAT_DI_R = fh.variables['TAT_DI_R'][:]
#      16 len_tat=len(TAT_DI_R)
#
# KeyError: 'PAL_RVS'

# %%
a=[1,2,3,7,5]

# %%
print,a(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-24247e8e1877> in <module>()
# ----> 1 print,a(2)
#
# TypeError: 'list' object is not callable

# %%
print,a[2]
# Out:
# (<function print>, 3)

# %%
import numpy as np
from netCDF4 import Dataset
import glob
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import math


fh = Dataset('core_faam_20160303_v004_r0_b947.nc','r')
wow=fh.variables['WOW_IND'][:]
lat = fh.variables['LAT_GIN'][:]
time = fh.variables['Time'][:]
PALT_RVS = fh.variables['PALT_RVS'][:]
TAT_DI_R = fh.variables['TAT_DI_R'][:]
LWC_JW = fh.variables['LWC_JW_U'][:]
#number of seconds worth of data in the temperature parameter
len_tat=len(TAT_DI_R)
TempProfile=np.array(TAT_DI_R)
ProfileFlag=np.array(TAT_DI_R)
#print (PALT_RVS[0])
print (len(PALT_RVS))

for i in range (0,(len(PALT_RVS)-1),1):

    if np.mean(PALT_RVS[i])<=(np.mean(PALT_RVS[(i+1)])-2):
        TempProfile[i]=1
    elif np.mean(PALT_RVS[i])>=(np.mean(PALT_RVS[(i+1)])+2):
        TempProfile[i]=2
    else:
        TempProfile[i]=0 
        
for i in range (0,(len(PALT_RVS)-1),1):
    if TempProfile[i,0]==1 and TempProfile[i,1]==1 and TempProfile[i,2]==1 and TempProfile[i,3]==1 and TempProfile[i,4]==1 and TempProfile[i,5]==1 and TempProfile[i,6]==1 and TempProfile[i,7]==1 and TempProfile[i,8]==1 and TempProfile[i,9]==1 and TempProfile[i,10]==1 and TempProfile[i,11]==1 and TempProfile[i,12]==1 and TempProfile[i,13]==1 and TempProfile[i,14]==1 and TempProfile[i,15]==1:
        ProfileFlag[i]=1
    elif TempProfile[i,0]==2 and TempProfile[i,1]==2 and TempProfile[i,2]==2 and TempProfile[i,3]==2 and TempProfile[i,4]==2 and TempProfile[i,5]==2 and TempProfile[i,6]==2 and TempProfile[i,7]==2 and TempProfile[i,8]==2 and TempProfile[i,9]==2 and TempProfile[i,10]==2 and TempProfile[i,11]==2 and TempProfile[i,12]==2 and TempProfile[i,13]==2 and TempProfile[i,14]==2 and TempProfile[i,15]==2:
        ProfileFlag[i]=2
    else:
        ProfileFlag[i]=0

#very simple, assuming a threshold for jw of 0.05
for i in range (0,(len(PALT_RVS)-1),1):
    if np.mean(LWC_JW[i])>0.05:
        ProfileFlag[i]=ProfileFlag[i]-5
    else:
        ProfileFlag[i]=ProfileFlag[i]

for i in range (0,(len(PALT_RVS)-1),1):
    if wow[i]==0:
        ProfileFlag[i]=ProfileFlag[i]
    else:
        ProfileFlag[i]=-10

        
        

#x = np.arange(0, 10, 0.1)
#y1 = 0.05 * x**2
#y2 = -1 *y1

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(time, PALT_RVS, 'g-')
ax2.plot(time, ProfileFlag, 'b')

ax1.set_xlabel('Time (seconds since midnight')
ax1.set_ylabel('Altitude (m)', color='g')
ax2.set_ylabel('Flag', color='b')
ax1.set_ylim(0,)
ax2.set_ylim(-12,4)

#text(3100,2400,'0 = level, no cloud')
#ax2.text(0.5, 0.5, '0 = level, no cloud')
#ax2.text(0.5, 0.4, '1 = up, no cloud')
#ax2.text(0.5, 0.4, '1 = up, no cloud')
#ax2.text(0.5, 0.4, '1 = up, no cloud')
#ax2.text(0.5, 0.4, '1 = up, no cloud')
#ax2.text(0.5, 0.4, '1 = up, no cloud')

#ax2.annotate('2 = down, no cloud', xy=(0,4000), xytext=(3100,2200))
#ax2.annotate('-5 = level, cloud', xy=(0,4000), xytext=(3100,2100)) 
#ax2.annotate('-4 = up, cloud', xy=(0,4000), xytext=(3100,2000))
#ax2.annotate('-3 = down, cloud', xy=(0,4000), xytext=(3100,1900))    
#ax2.annotate('10 = on ground', xy=(0,4000), xytext=(3100,1800))
              #       1(up, no cloud) 2(down, no cloud) -5(level, cloud) -4(up, cloud) -3(down, cloud)-10(on ground)', xy=(2, 1), xytext=(3, 1.5),
     

plt.show()

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(time, LWC_JW, 'g-')
ax2.plot(time, ProfileFlag, 'b')

ax1.set_xlabel('Time (seconds since midnight')
ax1.set_ylabel('Liquid water content (arb. units)', color='g')
ax2.set_ylabel('Flag', color='b')
ax1.set_ylim(0,)
ax2.set_ylim(-12,4)

plt.show()
#plt.plot(time,PALT_RVS)
#plt.plot(time,TempProfile)
# Out:
# 25006
